# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv(r"C:\Users\Lenovo\نجوم پروژه\IC 348.csv")
print (data.columns)
print (data.head())

absolute_magnitude=data['phot_g_mean_mag']
color_index = data['bp_rp']

plt.figure(figsize=(20,6))
plt.scatter (color_index, absolute_magnitude, s=50, c='blue', alpha=0.7)
plt.gca().invert_yaxis()
plt.title('Hertzsprung-Russell Diagram')
plt.xlabel('Color Index (B-V)')
plt.ylabel('Absolute Visual Magnitude')
plt.grid(True)
plt.savefig('IC 348.png')
plt.show()
# Out:
# Index(['designation', 'source_id', 'ra', 'dec', 'parallax', 'pmra', 'pmdec',
#        'ruwe', 'phot_g_mean_mag', 'bp_rp', 'radial_velocity',
#        'phot_variable_flag', 'non_single_star', 'has_xp_continuous',
#        'has_xp_sampled', 'has_rvs', 'has_epoch_photometry', 'has_epoch_rv',
#        'has_mcmc_gspphot', 'has_mcmc_msc', 'teff_gspphot', 'logg_gspphot',
#        'mh_gspphot', 'distance_gspphot', 'azero_gspphot', 'ag_gspphot',
#        'ebpminrp_gspphot'],
#       dtype='object')
#                     designation            source_id          ra        dec  \
# 0  Gaia DR3 5976330551538763648  5976330551538763648  256.154186 -37.988490
# 1  Gaia DR3 5976330551538768768  5976330551538768768  256.159363 -37.989278
# 2  Gaia DR3 5976331341860023552  5976331341860023552  256.130399 -37.970413
# 3  Gaia DR3 5976330207941442688  5976330207941442688  256.190126 -38.005327
# 4  Gaia DR3 5976330207941450240  5976330207941450240  256.182450 -38.013138
#
#    parallax  pmra  pmdec  ruwe  phot_g_mean_mag     bp_rp  ...  has_epoch_rv  \
# 0       NaN   NaN    NaN   NaN              NaN       NaN  ...         False
# 1       NaN   NaN    NaN   NaN        20.588158       NaN  ...         False
# 2       NaN   NaN    NaN   NaN        20.390877       NaN  ...         False
# 3       NaN   NaN    NaN   NaN        20.984602  1.348890  ...         False
# 4       NaN   NaN    NaN   NaN        20.690092  1.974379  ...         False
#
#   has_mcmc_gspphot  has_mcmc_msc  teff_gspphot  logg_gspphot  mh_gspphot  \
# 0            False         False           NaN           NaN         NaN
# 1            False         False           NaN           NaN         NaN
# 2            False         False           NaN           NaN         NaN
# 3            False         False           NaN           NaN         NaN
# 4            False         False           NaN           NaN         NaN
#
#    distance_gspphot  azero_gspphot  ag_gspphot  ebpminrp_gspphot
# 0               NaN            NaN         NaN               NaN
# 1               NaN            NaN         NaN               NaN
# 2               NaN            NaN         NaN               NaN
# 3               NaN            NaN         NaN               NaN
# 4               NaN            NaN         NaN               NaN
#
# [5 rows x 27 columns]
